# %% [markdown]
# <a href="https://colab.research.google.com/github/FathimaHaseeb/hellohi/blob/main/Copy_of_Python_Project_Employee_Attrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analyse Employee Attrition

# %% [markdown]
# ## Task

# %% [markdown]
# Uncover the factors that lead to employee attrition.
#
# 1. Have a look at the variables, understand what they are.
# 2. Which variables are associated with attrition? For which groups of employees
# does this association hold (`Department`, `JobLevel`, etc.)? Formulate several hypotheses.
# 3. Explore each hypothesis.
#     - Make plots and/or compute statistics.
#     - Write a short conclusion, refer to the justifications you found in the data.

# %% [markdown]
# ## Dataset

# %% [markdown]
# _Source: https://www.kaggle.com/datasets/whenamancodes/hr-employee-attrition_
#
# This is a fictional data set created by IBM data scientists. It contains data about employees in a company.
#
# Encoding of some of the columns:
#
# ```
# Education
# 1 'Below College'
# 2 'College'
# 3 'Bachelor'
# 4 'Master'
# 5 'Doctor'
#
# EnvironmentSatisfaction
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# JobInvolvement
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# JobSatisfaction
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# PerformanceRating
# 1 'Low'
# 2 'Good'
# 3 'Excellent'
# 4 'Outstanding'
#
# RelationshipSatisfaction
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# WorkLifeBalance
# 1 'Bad'
# 2 'Good'
# 3 'Better'
# 4 'Best'
# ```

# %% [markdown]
# ## Analysis

# %%
import pandas as pd
import seaborn as sns

# From https://drive.google.com/file/d/1TGVkYpXg9efkuh-N3UCaahBtCQhs65vy/view
df = pd.read_csv(
    "https://drive.google.com/uc?id=1TGVkYpXg9efkuh-N3UCaahBtCQhs65vy",
    true_values=["Yes"],
    false_values=["No"],
)
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       True      Travel_Rarely       1102                   Sales
# 1   49      False  Travel_Frequently        279  Research & Development
# 2   37       True      Travel_Rarely       1373  Research & Development
# 3   33      False  Travel_Frequently       1392  Research & Development
# 4   27      False      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20,10))
sns.heatmap(df.corr(method="kendall"), annot=True, fmt=".3f", ax=ax);
# Out:
# <ipython-input-56-29c33dbf1d10>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method="kendall"), annot=True, fmt=".3f", ax=ax);

# %%
# Correlation Coeficient Range [-1 - 1]

#-1 is perfectly negative Correlation
#1 is perfect positive correlation

# %%
df.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
#print(cars.query('Year >= 2016 & Make == "Ford"').shape)

df.query("Age > 40 & Department =='Sales'")
# Out:
#       Age  Attrition     BusinessTravel  DailyRate Department  \
# 0      41       True      Travel_Rarely       1102      Sales
# 18     53      False      Travel_Rarely       1219      Sales
# 27     42      False      Travel_Rarely        691      Sales
# 29     46      False      Travel_Rarely        705      Sales
# 36     50       True      Travel_Rarely        869      Sales
# ...   ...        ...                ...        ...        ...
# 1448   41      False      Travel_Rarely        930      Sales
# 1452   50       True  Travel_Frequently        878      Sales
# 1454   45      False      Travel_Rarely        374      Sales
# 1461   50       True      Travel_Rarely        410      Sales
# 1468   49      False  Travel_Frequently       1023      Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 18                   2          4  Life Sciences              1
# ...

# %%
sns.barplot(data=df, x="MonthlyIncome" , y="JobLevel")
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='JobLevel'>

# %%
col=['MonthlyIncome','JobInvolvement','JobLevel', 'JobRole']
df.loc[[0,1,2,3,4],col]
# Out:
#    MonthlyIncome  JobInvolvement  JobLevel                JobRole
# 0           5993               3         2        Sales Executive
# 1           5130               2         2     Research Scientist
# 2           2090               2         1  Laboratory Technician
# 3           2909               3         1     Research Scientist
# 4           3468               3         1  Laboratory Technician

# %%
df[(df.Department == "Research & Development") & (df.EducationField =="Life Sciences") ]["Age"].count()
# Out:
# 440

# %%
#df['Age'].groupby(['Department','EducationField']).count()
ab=df.groupby(['Department','EducationField','Attrition'])['Age'].count().to_frame('count').reset_index()
ab['dep_edu']=ab['Department']+'_'+ab['EducationField']
print(ab)
# Out:
#                 Department    EducationField  Attrition  count  \
# 0          Human Resources   Human Resources      False     20
# 1          Human Resources   Human Resources       True      7
# 2          Human Resources     Life Sciences      False     15
# 3          Human Resources     Life Sciences       True      1
# 4          Human Resources           Medical      False     11
# 5          Human Resources           Medical       True      2
# 6          Human Resources             Other      False      3
# 7          Human Resources  Technical Degree      False      2
# 8          Human Resources  Technical Degree       True      2
# 9   Research & Development     Life Sciences      False    381
# 10  Research & Development     Life Sciences       True     59
# 11  Research & Development           Medical      False    316
# 12  Research & Development           Medical       True     47
# 13  Research & Development             Other      False     57
# ...

# %%
df['dep_edu']=df['Department']+'_'+df['EducationField']
df = df.drop(columns=['count'])

# %%
df.head()

# %%
sns.barplot(x='dep_edu',y='count',hue='Attrition',data=ab)
# Out:
# <Axes: xlabel='dep_edu', ylabel='count'>

# %%
#the Research & Development Department experiences higher attrition rates when there is a higher proportion of employees with Life Sciences.

# %%
bc=df.groupby(['YearsSinceLastPromotion','Department','Attrition'])['Age'].count().to_frame('count').reset_index()
#bc['dep_attr']=bc['Department']+'_'+bc['Attrition']
print(bc)
# Out:
#     YearsSinceLastPromotion              Department  Attrition  count
# 0                         0         Human Resources      False     18
# 1                         0         Human Resources       True      6
# 2                         0  Research & Development      False    314
# 3                         0  Research & Development       True     65
# 4                         0                   Sales      False    139
# ..                      ...                     ...        ...    ...
# 63                       14                   Sales      False      1
# 64                       14                   Sales       True      1
# 65                       15  Research & Development      False      5
# 66                       15  Research & Development       True      3
# 67                       15                   Sales      False      5
#
# [68 rows x 4 columns]

# %%
sns.barplot(x='Department',y='count',hue='Attrition',data=bc)
#Research & Development have larger attrition rate due to long gap of year of promotion
# Out:
# <Axes: xlabel='Department', ylabel='count'>
